# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("LOPO_machnism.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("expert_labeling.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("red_black_poles.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("aaaaaaaaaaaa_true_exclude_label_200_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("aaaaaaaaaaaa_cana_exclude_label_200_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("aaaaaaaaaaaa_true_exclude_auto_label_200_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()
