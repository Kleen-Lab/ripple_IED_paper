# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# Create figure without frame
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("transformer_arch.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
# Create figure without frame
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("transformer_machism.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("auc_roc_true_5_fold_200_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("auc_roc_cana_5_fold_200_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("aaaaaa_prauc_200_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
# Create figure without frame
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("aaaaaa_prauc_200_true_add.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()

# %%
fig = plt.figure(frameon=False, figsize=(25, 25))

image = cv2.imread("from_matlab_psudo_manual.png")  # Replace with your image path
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for correct colors in Matplotlib

# Display image
plt.imshow(image)
plt.axis("off")  # Hide axes
plt.show()
